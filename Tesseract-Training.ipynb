# %%
import pytesseract

# %%
import cv2
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import numpy
import numpy as np

# %%
import sys
import os

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    #return cv2.cvtColor(image,cv2.COLOR_BGR2HSV)  #this is to make the image in HSV form that is used to detect object

# %%
#thresholding is done to make the intensity more clear...
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# %%
img=cv2.imread('eng.arial.exp3.jpg')

# %%
plt.imshow(img)

# %%
C

# %%
plt.imshow(thresh)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(img, config=custom_config)
# Out:
# "S10P_ CRUELTY To ANIMALS AND GIRDS\n89 i poo 1\ns ood Morning te al\\ respected teachers ,Meneurable\n[judges and all my dear friends . tiarn here today to\nwe a Speech onthe topic - © stop cruelty to animals\nand birds’ - zi (oN 1\nHuman life ss precious but my friends, aninna\\ oy\nJoirds life is algo Valuavie. ot is of utmost importance\nsee animals whipped , beaten , starved and treated crue}\nthat must be Stopped. We must learn te be sensitive Te\nanimals of birds . they may be dump creatures but th\n| too have FEELINGS | TH algo Feel pain or joy .- Tt iS\nnecessary TO teach youngstert who Will grow inte adults\nkhat animals must be treated — _ Animals and birds\nave a necessary part of oT ecosystem. They enhance\nhuman life - These creatures bring joy +s many and it\n| 3s also fairy that Human beings showd appreciate value\nof them - So, SHOP treating animals and birds cruelly or\nby Unfair means and don't Utilixe them +e bring [oy or\nhappiness for yourself . Stop killing the
# ...

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, config=custom_config)
# Out:
# "g10P CRUELTY TO ANIMALS AND BIRDS\npare pot EE\nood Morning te all respected teachert , honourable\nsydges and all my dear ériends . tiamm here today to\nve a speech on rhe topic - ‘ stop Cruelty to animals\nand biyds’. He wip) 1/0\nTce, Nespas but my friends , animal ey\n[birds life is also Valuable. Tt is of utmost importance\nJee treat these creatures with love and respect « We often _\n| see animais whipped , beaten , starved and treated eruely —\nthat must be stopped. We must jean 10 be sensryive To _\nanimals of birds . They may be dump creatures but th:\n|_ necessary 10 teach youngsters uso will grow inte adults\n| that animals must be treated kindly + Animals and birds\n| ave a necessary part. of our ecosystem . They enhance\n| juman life - These creatures bring joy ts many and it\n| js also faty that buman beings showld apprediare value\nof them. So, Stop treating animals and birds cruelly or\nby UNFair means and don't Utilixe them +e bring [oy or\nhappiness for yourself . 
# ...

# %%
*custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config=custom_config)
# Out:
# "Siep_ CRUELTY Te ANIMALS AND BIRDS\n_ TT\npod Morning te all_respected teachert, Monouy able\nwudges. and_all my dear friends . t_am here today te —_—\nve a speech onrme topic - ¢ Step Cruelty 72 animals —__\nand bivds’. _ oo\na viman tie ve precious but my friends animal ey\nleivds life ig also valuable Ty is of utmost importance —\nTye treat these creatures with love and respect - we often _\n|| see animals whipped , beaten , starved and treated cruelly —\nthat must be stopped. We must team 10 be sensitive Fo\nanimals or birds - They may be dump creatures but th\n|_mecessary TO teach youngster whe witl grew imta aduiy\n[that _animais must be treated kindly - Animals and birds\n1 ave a necessary part of our ecosystem . They enhance\n{| uman life - These creatures bring joy ts Many and it\n| 1S G\\So faty that buman beings showd appreciate value\nof them .So, StoP treating animals and birds cruetly or\ney unfaiy means and don't Utilixe them +e bring joy or\nhappiness for yourself. S
# ...

# %%
pytesseract.image_to_string(gray,lang='1+eng+2')
# Out:
# 'g1oP CRUELTY TO ANIMALS AND BIRDS\n\n \n\n \n\n \n\n| Good Morning ts al\\ respected teachert , Honourable\n+\n\nsudges and all my dear Friends . tam here today +o\nZI : mee ane\niswie +b Speschion me stele stop Crueiy to anima\n\n \n\n \n\nand biyds’. e ‘\nee Human life (s precious but my triends , animal or\n[birds life (s also valuable Tt is of utmost irmportance\n|bo treat these creatures with love and respect . We of ter\nset animals whipped , beaten , starved and treated eruely\nthat must be Stopped. We must earn +o be SensyHive =\n\nanimals or birds . they may be dump creatures but they\n\n \n\ntoo have Feelings . They also Feel PAIN or joy site tS\nnecessary TO teach youngstert who Will grow inte adults\nkat animals must be treated kindly « Animals and wirds\naye a necessary part of our ecosystem . They enhance\nhuman life - These creatures bring joy te many and it\nis also fair that »uman beings showd apprediate value\nof +hem So, STOP treating animals and birds cruelly, or
# ...

# %%
#gray is the best
lets train the model on gray

# %%
cv2.imwrite('eng.arial.exp3.tiff',gray)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp4.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'

pytesseract.image_to_string(gray,  config=custom_config)
# Out:
# 'yardness. 11 can alco lad upt 40 years\n(9) PABLLCLE BOARD ir Th economlaah\nand made up of yawdusl > Bul\nite nol duvable as MpF\n@O-7YPES OF FINISHES™*#\nFinishes can_inevease the life\nof the mateial_wed- 1} also\nhelps te _ehance an wooden\npiece Sin Various wale ii Ss\n() Matte: Finish t=} will havea\n"natural wood look — —____\n® lossyefinishe i Coated with the —\nlay _of_pelyorethane_, this finish\nSic ideal orl a usleekbilooktesw na\n@apolish -- Tt brin 1 the natural\nMalou grain 4 ptiern of oaed\nEmenee okie\npo ich that consists of a thin\n—layer_ol x esin: Jt 4i ves dhe\n~ glossy looks to the word:'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, lang='eng+3')
# Out:
# "yardness. 11 can alco lad upt 40 years\n\na eenteanur Th e¢onomical.\nand made al wawdust > But\nits mod Ayal as MOF\n\n(D- TYPES OF FINISHES ™**\nFinishes can_inevease the life\nof the matuial wed 1} also\nhelps — to enhance any wooden\npiece in vatious wale:\n\n(. ) Matte Finish so [+ will havea\n~ natural wood look\n\n@. 2 diese f= Cpatedortth toe\ncow of _polyorethane, this finish\nmn Abr Ld asiezekh ton kt es ees\n\n() afolish '- - Tt brings the vatuval\n—_tolour ain 4 patlern of wood:\n\n@.ttelamie Coating ts, kind of\n—polich that _consis!s__of a. thin a\n\nen qives_dhe\na Poison a"

# %%
cv2.imwrite('eng.arial.exp4.tiff',gray)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp10.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, config= custom_config )
# Out:
# 'ee tk,\nSoya Sane —- 200g\n(ili Sauce, - 2004\nRed thille (Dry) is 1004\n, q\nNoodles : & pkT ’\n; ere sete ‘\n Bisailts = 10oMs\n Adartam MATOS — 1PS)\ner\na. Bs pe re ee :\na : 5. 5 eS\nae\na) ge\nipa Bi\n3 ¢ Fs\nae'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray,  lang='eng+2+1+3')
# Out:
# "Goua Sauce - 2005\nnil Same —2004\n\nRed chille (Dry) _ (00q_\nNoodles - Apr\n'pisults Sn"

# %%
cv2.imwrite('eng.arial.exp10.tiff',gray)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp3.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
pytesseract.image_to_string(gray,  lang='3+eng')
# Out:
# 'sT0PCRuCRTTTCAAAllIllA-lAlSAAND BIRDS\n\n \n\n \n\n \n\n| Good Morning ts al\\ respected teachert , Honourable\n+\n\nsudges and all my dear Friends . tam here today +o\nZI A PR Pls\nAdkcospccchnvnnoloplc sAcRp—CruuTvAToonln-m\n\n \n\n \n\nondbnnAdswwAA A A\nA HuASnAonIIpClSprecdlowbulmv erspndson—lmoln\nRAEPdslmfpcAsononolAuowban-hllSofulmosl —lmPononcc\nAsocrpdlThcgspcrerhdpleyThlovpnl—ldrpsRecd-wconen\nsgconGmomSwh—lpppdsbcolcnslovvpdondlrcoEd crucgu\npholmusbbesnppedoldcmusclyom—mbcssnsl—kp =\n\nanimals or birds . they may be dump creatures but they\n\n \n\ntoo have Feelings . They also Feel PAIN or joy site tS\nnecessary TO teach youngstert who Will grow inte adults\nkat animals must be treated kindly « Animals and wirds\naye a necessary part of our ecosystem . They enhance\nhuman life - These creatures bring joy te many and it\nis also fair that »uman beings showd apprediate value\nof +hem So, STOP treating animals and birds cruelly, or\nboy Unfair means and don’t Utilixe them 
# ...

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, lang='eng')
# Out:
# 'g1oP CRUELTY TO ANIMALS AND BIRDS\n\n \n\n \n\n \n\n| Good Morning ts al\\ respected teachert , Honourable\n+\n\nsudges and all my dear Friends . tam here today +o\nZI : mee ane\niswie +b Speschion me stele stop Crueiy to anima\n\n \n\n \n\nand biyds’. e ‘\nee Human life (s precious but my triends , animal or\n[birds life (s also valuable Tt is of utmost irmportance\n|bo treat these creatures with love and respect . We of ter\nset animals whipped , beaten , starved and treated eruely\nthat must be Stopped. We must earn +o be SensyHive =\n\nanimals or birds . they may be dump creatures but they\n\n \n\ntoo have Feelings . They also Feel PAIN or joy site tS\nnecessary TO teach youngstert who Will grow inte adults\nkat animals must be treated kindly « Animals and wirds\naye a necessary part of our ecosystem . They enhance\nhuman life - These creatures bring joy te many and it\nis also fair that »uman beings showd apprediate value\nof +hem So, STOP treating animals and birds cruelly, or
# ...

# %%
img = cv2.imread('eng.arial.exp11.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
plt.imshow(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, lang = '1+ eng' )
# Out:
# 'oae cdon a Rehn touacd a scWoSShooo ono ncucs\n\nW Sioleusouc u ue cluaclchg nna ouni Snsuced Sin uR\n\nW oad Sano iinl to hls Ren nule n SsuSt. isheo ioe Soaad\n\nh alaothn scWoShoonS . ue ReRn lchanc oae toc hln\nu.SRtsSnSoso udi.s'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, lang = '2+ eng' )
# Out:
# 'oa—B Cdag a RthCl Goui—icd a stMoBiooi—SB ono ugc-g\n\nW SiolBugaik - uo oichig roi—s ouni SgSRde Sin uB\n\nB aiid ganB ini to WS Bn nun - —SsuSt. tshng ioc r-ouod\n\nr alaothn scnioShoono—n . uG— kBBn uga—c ooR tor l—MM—g\nu—SasB—rBoso —C-.g'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# 'gM .\noe\nyer A ean\nOne Gay, a Zebra found a xylophone om the\nsidewalk . He quickly van over ejcked it UP,\nand gave it to pis pet mule - Just then ne found\nanother x ylophone . We ke pt nat one for Him -\n4234567890 -/*)\na\na\na'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, config = custom_config)
# Out:
# 're -\n3\nfie:\nOne day, a Zebra found a _ xylophone oM tbe\nBidewalk . He quickly ran over efckxed it UP,\nand gave it to bis pet mule - Just then ne found\nanother x ylophone Ne kept Hart one for Him -\njae 2) So one fe SO On. fie?)\nRM Me er\na oe es hh eel\ni ee en te'

# %%
cv2.imwrite('eng.arial.exp11.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp13.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# '\\ | oy\nSo\n~ One day, a zebta found a xylephone _\n—_picked_it up, and gove it Fee\npet mule: Just th 5 he found\nanother xylophone . He kept that\n‘one for himself. 1234 5 6 7 3930\noo\noe\nTi\neee\na\nTi\nff\n|'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, config = custom_config)
# Out:
# '| 3 ay\nOM\nTone day, a zebra found a xylophepe —\ngE picked_it up, and gave (tte\npet mule: Just th ; he found\nanother xylophone He kept that\n‘one for himself. 1234 5 67 890\nSere ee ee\nRe\ni aaa\neee ree ee\nEee eerie\nee\na\n|'

# %%
cv2.imwrite('eng.arial.exp13.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp14.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
plt.imshow(thresh)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# 'A (One day 1a zebta fourd a xylophone J\ni he Sidewalk : He quickly yan over. vpicked tt. ——\n, yp tand gave it to hig mule. Tust then,\nBe founded another xylophone- He Kept that ——\n| nef  himger#e 1234567¢9 2-12)\n_— ee'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, config = custom_config)
# Out:
# '1 ( One day 14a zebta found a xylophone —_\n1 ne Sidewalk + He quickly yan over , picked 1\n| p 1and gave it to his mule. tugt -then, a\n||) he founded another xylophone- He Kept that ——\np ne Phimeeyf?. 10 3456 7 ¢ 9 =\n— aia ='

# %%
cv2.imwrite('eng.arial.exp14.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp15.jpg')
plt.imshow(img)

# %%
img=cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(img)

# %%
img=cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(img)

# %%
img=cv2.rotate(img,cv2.ROTATE_180)
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
plt.imshow(thresh)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# 'One doy a zebka. found a Ky Leph One, On H@ Sidewalh\n\nHe qu Yon over, Picked it up, & gave it to Aig Pet\nmule . Tut Them, he found another xyephone . He\nkebx that One dos him Bel.'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, config = custom_config)
# Out:
# 'One doy a zebsa. found @ Ky Loph one, On He Sidewalh\n\nRe qua Yom over Picked it up, & gave ik to Aig Pet\nmule. Tur Them, he found another xyephone. . He\nkebk that One Jk him Sel).'

# %%
cv2.imwrite('eng.arial.exp15.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp16.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# 'a 8 : *S\n—One day, 1 zebra. found a xuloshane My\n——on_tlae “sidewalk He quickly, va aver, S <\nfile Tad then ond aie\n\nxulophane He Kept that one for himselt.A\n\n0 A C 990 - 2) . t\n\nSo\na\nTO\nee,'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, config = custom_config)
# Out:
# 'ee a ‘ i:\n—One_day_,o_zebra found a._xuylophone SY\n—on_thhe “sidewalk He quickly, over, y s\nfile Tat then oud ante\nxulophone . He Kept that one for himselt.&\n\n0 A C 990 - 35) F +\nI\nir\nsee cs\nOE ES iil'

# %%
cv2.imwrite('eng.arial.exp16.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp18.jpg')
plt.imshow(img)

# %%
img=cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# '“Fhe dp ya hin lee oa ei\nHe guclfy Har aust ft Lt up» arel gous dt th\n—Ait__pet mule. dist then, he -uocthwt — Xedlgphare-__\nA fe Hag, OS ON I'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, config = custom_config)
# Out:
# 'a es\n— He quietly Ho aust, cn Lt typ» aurol gous bt ty —_\nhit fet mule. ist then, he -Cunothot —Xulgphare -—_\nSe ee'

# %%
cv2.imwrite('eng.arial.exp18.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp19.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# '“ne_sloy a Zobin four a —nplopasne\n—onn foe stele iwrntde, He _quiitele, Atos\noy _bGa pet onaulle Just then fhe pelat\n—thot one for itmself 12 24564290 —_'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, config = custom_config)
# Out:
# '“tine_sloy oben four a xylose\nona __the golem de, He _quistefey, A oxae ———\nob fix pet mule Just then fhe Jeehat\nthot one for htmselt 12 54-56% 29.0'

# %%
cv2.imwrite('eng.arial.exp19.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp20.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, config = custom_config)
# Out:
# 'a @. *\n_ ai - {im :\n\naa ’ S ‘\n\ni efoprors\n\n£ wy & dat 1\npos ee\nae\n\n; ae ,\n\nBes :\nae'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# 'te. +@.. .\nan ay we tie r\n\na r. : _ .\n\nBOOETa phone\n\n~ ae AU 7\n\nwere Tee\nSS a\n\n; aaa ,\n\n™\n- 3'

# %%
cv2.imwrite('eng.arial.exp20.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp21.jpg')
plt.imshow(img)

# %%
img=cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# '1 OT a sk\n; oo. - - - —- J A\nPT . 4\nee 4\nbe . 4\nI —ORE_AAXY A _zebsa found a xyjophone an se |\n+ Side AK .- te _quickiy “son ovex__picked YW WP _ |\n|. AA _QaVE I} +o_pis per mwe . Tus tren ne 1\n_ found anothey xyophone , He Kept +hot_ore Fox_ td\nCPO __ If\n- 234656678990 -/ ) 42\neee\n_ a ——- — —tee\nVN\nSU 68\n>\n“= “> -S oO Ngee\na'

# %%
cv2.imwrite('eng.arial.exp21.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp23.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(gray, config = custom_config)
# Out:
# '.\nI 5 bra dag 0 pebra pound a x qhophone _\non the adealh | Te GEE eee\nnicttd ak Lip, And gare at An AS ern 4\n"guat then, Me FO Ae\n| Lt kip Oat De Te ee\nyl a ie 2. as G & o ,\n\' a8 Ba Ses ae ne A 2 et 2 se 7 © / i )'

# %%
cv2.imwrite('eng.arial.exp23.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp24.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# 'ee . [ PagoNo |\nean an a\na can gn ee\nterpenes aera paren\nae Rr tr ph gO\noS (One day a zebra found a xy lophane\n: + d Ik _H ck of\nay =\n\nae'

# %%
cv2.imwrite('eng.arial.exp24.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp25.jpg')
plt.imshow(img)

# %%
img=cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# '(One day, a geloa found a xylythout os;\n——'

# %%
cv2.imwrite('eng.arial.exp25.tiff',thresh)
# Out:
# True

# %%
img=cv2.imread('eng.arial.exp16.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# 'a 8 : *S\n—One day, 1 zebra. found a xuloshane My\n——on_tlae “sidewalk He quickly, va aver, S <\nfile Tad then ond aie\n\nxulophane He Kept that one for himselt.A\n\n0 A C 990 - 2) . t\n\nSo\na\nTO\nee,'

# %%
 pytesseract.image_to_string(thresh, lang='eng+16+11+13+14+21+24',  \
        config='--psm 6 --oem 3 ')
# Out:
# 'a 8 : *S\n—One day, 1 zebra. found a xuloshane My\n——on_tlae “sidewalk He quickly, va aver, S jj j.\nfile Tad then ond aie\n\nxulophane He Kept that one for himselt.A\n\n0 A C 990 - 2) . t\n\nSo\na\nTO\nee,'

# %%
img=cv2.imread('eng.arial.exp11.jpg')
plt.imshow(img)

# %%
gray=get_grayscale(img)
thresh=thresholding(gray)

# %%
 pytesseract.image_to_string(thresh, lang='eng+16+11+13+14+21+24',  \
        config='--psm 6 --oem 3 ')
# Out:
# 'gM .\n.S__q\n=2=“qu\nOEdQ)QZCbKQGOundeN/)NQQQEQT)H)C\nqququKjHEwCKqKQnOx/ET SCquHua\nondovqpk.bc)mqqumuhq.JuST—H)CT) ne found\nanother x ylophone . We ke pt nat one for Him -\n4234567890 -/*)\na\na\na'

# %%
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(thresh, config = custom_config)
# Out:
# 'gM .\noe\nyer A ean\nOne Gay, a Zebra found a xylophone om the\nsidewalk . He quickly van over ejcked it UP,\nand gave it to pis pet mule - Just then ne found\nanother x ylophone . We ke pt nat one for Him -\n4234567890 -/*)\na\na\na'

# %%
 pytesseract.image_to_string(thresh, lang='eng',  \
        config='--psm 6 --oem 3 ')
# Out:
# 'gM .\noe\nyer A ean\nOne Gay, a Zebra found a xylophone om the\nsidewalk . He quickly van over ejcked it UP,\nand gave it to pis pet mule - Just then ne found\nanother x ylophone . We ke pt nat one for Him -\n4234567890 -/*)\na\na\na'
